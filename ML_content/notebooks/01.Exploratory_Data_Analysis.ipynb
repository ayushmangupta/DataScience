# %% [markdown]
# # Exploratory Data Analysis
#
# Definition of EDA:
#
# Exploratory Data Analysis(EDA) is an approach to analyzing data sets to summarize their main characteristics, often with visual methods. A statistical model can be used or not, but primarily EDA is for seeing what the data can tell us beyond the formal modeling or hypothesis testing task.
#
# Some reasons why EDA is necessary:
#
# * Initial investigations of the data reveal many underlying patterns and insights.
# * To know datatypes we are operating on.
# * Null value treatment.
# * Outlier Detection.
#
# Source: [Wikipedia](https://en.wikipedia.org/wiki/Exploratory_data_analysis)

# %%
# import required libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# plot stylings
plt.style.use('fivethirtyeight')
# %matplotlib inline

# do not display warnings in notebook 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Reading data
#
# > We use [pd.read_csv](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) to read csv files.

# %%
# read the input file
data = pd.read_csv("../data/titanic/train.csv",)

# %%
# display the first rows in the data
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# get the shape of the dataframe
data.shape
# Out:
# (891, 12)

# %% [markdown]
# ### Null Value treatment
#
# > Missing values in data is a common phenomenon in real world problems. Knowing how to handle missing values effectively is a required step to **reduce bias** and to build better models.

# %%
# check for null values
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# * Only the 'Age' and 'Cabin' columns have missing values.
# * Out of the 891 samples, 687 samples have missing 'Cabin' values. Imputing this value is of less use since it adds a lot of bias in the training data.

# %% [markdown]
# ### Value Count plots
#
# > Plotting value counts gives us the class or categorical distribution of the data. Not taking class imbalance into account results in poorly generalized model.

# %%
f,ax=plt.subplots(1,2,figsize=(12,6))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# * 38.4% of the passengers aboard survived the crash.

# %% [markdown]
# ## Categorical and Continuous Features
#
# Types of features:
#
# > **Categorical Features**: A categorical variable is one that has two or more categories and each value in that feature can be categorised by them.For example, gender is a categorical variable having two categories (male and female). Now we cannot sort or give any ordering to such variables. They are also known as Nominal Variables.
#
# > **Continous Feature**: A feature is said to be continous if it can take values between any two points or between the minimum or maximum values in the features column.

# %% [markdown]
# ### Categorical Features
#
# * Value counts is a necessary tool while operating on categorical features.
# * Other useful graphical tools for analyzing categorical data is a bar graphs, histograms.

# %% [markdown]
# #### Categorical Feature - Sex

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
data.groupby(['Survived','Sex'])['Sex'].count()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: Sex, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(12,6))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %% [markdown]
# * Survival ratio for females is much greater than that of males.

# %% [markdown]
# #### Categorical Feature - Pclass
#
# [pd.crosstab](https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.crosstab.html):
# > Compute a simple cross-tabulation of two (or more) factors. By default computes a frequency table of the factors unless an array of values and an aggregation function are passed
#
# Cross tabulation is used to quantitatively(generally based on frequency) analyze the relationship between multiple variables.

# %% [markdown]
# Survival rate with 'Sex' and 'Pclass' together

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row0_col1 {
#             background-color:  #cee666;
#             color:  #000000;
#         }    #T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row0_col2 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row1_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row2_col0 {
#             background-color:  #60b066;
#             color:  #000000;
#         }    #T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row2_col1 {
#             background-color:  #dfef66;
#             color:  #000000;
#         }    #T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row2_col2 {
#             background-color:  #90c866;
#             color:  #000000;
#         }    #T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row3_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row3_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row3_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_a4e2e882_88cb_11e9_afa0_4889e7d8b5a3row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### f,ax=plt.subplots(1,2,figsize=(12,6))
# data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
# ax[0].set_title('Number Of Passengers By Pclass')
# ax[0].set_ylabel('Count')
# sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
# ax[1].set_title('Pclass:Survived vs Dead')
# plt.show()

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row0_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row1_col0 {
#             background-color:  #96cb66;
#             color:  #000000;
#         }    #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row1_col1 {
#             background-color:  #a3d166;
#             color:  #000000;
#         }    #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row1_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row1_col3 {
#             background-color:  #cfe766;
#             color:  #000000;
#         }    #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row2_col0 {
#             background-color:  #a7d366;
#             color:  #000000;
#         }    #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row2_col1 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row2_col2 {
#             background-color:  #6eb666;
#             color:  #000000;
#         }    #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row2_col3 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row3_col0 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row3_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row3_col3 {
#             background-color:  #f7fb66;
#             color:  #000000;
#         }    #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row4_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row4_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row4_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row4_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row0_col2" class="data row0 col2" >72</td>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row1_col0" class="data row1 col0" >91</td>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row1_col1" class="data row1 col1" >70</td>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row1_col2" class="data row1 col2" >72</td>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3level1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row2_col0" class="data row2 col0" >77</td>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row2_col1" class="data row2 col1" >91</td>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row2_col2" class="data row2 col2" >300</td>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row3_col0" class="data row3 col0" >45</td>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row3_col1" class="data row3 col1" >17</td>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row3_col2" class="data row3 col2" >47</td>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3level0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3level1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row4_col0" class="data row4 col0" >216</td>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row4_col1" class="data row4 col1" >184</td>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row4_col2" class="data row4 col2" >491</td>
#                         <td id="T_c87bb494_8868_11e9_9efa_4889e7d8b5a3row4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Factor Plots :
#
# > A factor plot is simply the plot generated for a value with variables and arranged on a single axis.
#
# Here, from the below factor plots we can see the survival rates of passengers in differrent classes broken down by gender.

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %% [markdown]
# ### Continuous Feature - Age
#
# Continuous feature are dealt differently than ctegorical features:
# * Minimum Value and Maximum Value.
# * Mean, Mode and Meadian analysis.
# * Histogram plots and Violin plots.

# %%
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f,ax=plt.subplots(1,2,figsize=(12,6))
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# #### Violin Plots:
#
# > [**Violin Plots**](https://en.wikipedia.org/wiki/Violin_plot): A violin plot is a method of plotting numeric data. It is similar to a box plot, with the addition of a rotated probability density plot on each side.

# %% [markdown]
# #### Histogram Plots:
# > Histogram plot show the underlying frequency distribution of a continuous varible. The continuous variables in divided into bins and the frequency of data points the corresponding bins are plotted.

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()
