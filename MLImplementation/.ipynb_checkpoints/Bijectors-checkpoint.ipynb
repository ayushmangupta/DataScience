# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_probability as tfp
import tensorflow.distributions as tfd
tf.enable_eager_execution()

# %%
p_x = tfp.distributions.MultivariateNormalTriL(scale_tril=tf.cholesky([[1.0,.95],[.95,1.0]]))

# %%
samples = p_x.sample(1000)
print(samples)
# Out:
# tf.Tensor(
# [[-0.19548741 -0.01562729]
#  [-1.3859824  -1.0476481 ]
#  [-2.1154888  -2.2876816 ]
#  ...
#  [ 1.5533359   1.5729907 ]
#  [ 0.40272045  0.19670317]
#  [ 1.6662993   1.551692  ]], shape=(1000, 2), dtype=float32)

# %%
def forward_(samples):
    y1= samples[...,0:1]
    y2= samples[...,1:2] - (y1**2)  -1
    return tf.concat([y1,y2],axis=-1)

# %%
y = forward_(samples)

# %%
plt.figure(figsize=(12,5))
plt.subplot(121)
plt.plot(y[:,0],y[:,1],'.')
plt.subplot(122)

plt.plot(samples[:,0],samples[:,1],'.')

# %%
class Banana(tfp.bijectors.Bijector):
    def __init__(self,name="Banana"):
        super(Banana,self).__init__(inverse_min_event_ndims=1,name=name).__init__()
        
    
    
    
    def _forward(self,samples):
        y1= samples[...,0:1]
        y2= samples[...,1:2] - (y1**2)  -1
        y_tail = x[..., 2:-1]
        return tf.concat([y1,y2],axis=-1)
    
    
    def _inverse(self,y):

        x_0 = y[..., 0:1]
        x_1 = y[..., 1:2] + x_0**2 + 1
        x_tail = y[..., 2:-1]

        return tf.concat([x_0, x_1, x_tail], axis=-1)

# %%
p_y = tfp.distributions.TransformedDistribution(
    distribution=p_x,
    bijector= Banana()
)

# %%
data = p_y.sample(1000)

# %%
plt.figure(figsize=(7,5))


plt.plot(data[:,0],data[:,1],'.')

# %%
p_y.prob([.1,.5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-5b916d381670> in <module>
# ----> 1 p_y.prob([.1,.5])
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_probability/python/distributions/distribution.py in prob(self, value, name, **kwargs)
#     890         values of type `self.dtype`.
#     891     """
# --> 892     return self._call_prob(value, name, **kwargs)
#     893
#     894   def _call_log_cdf(self, value, name, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_probability/python/distributions/distribution.py in _call_prob(self, value, name, **kwargs)
#     872           value, name="value", dtype_hint=self.dtype)
#     873       if hasattr(self, "_prob"):
# --> 874         return self._prob(value, **kwargs)
#     875       if hasattr(self, "_log_prob"):
#     876         return tf.exp(self._log_prob(value, **kwargs))
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_probability/python/distributions/transformed_distribution.py in _prob(self, y, **kwargs)
#     436     distribution_kwargs, bijector_kwargs = self._kwargs_split_fn(kwargs)
#     437
# --> 438     x = self.bijector.inverse(y, **bijector_kwargs)
#     439     event_ndims = self._maybe_get_static_event_ndims()
#     440     ildj = self.bijector.inverse_log_det_jacobian(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_probability/python/bijectors/bijector.py in inverse(self, y, name, **kwargs)
#     975       NotImplementedError: if `_inverse` is not implemented.
#     976     """
# --> 977     return self._call_inverse(y, name, **kwargs)
#     978
#     979   def _compute_inverse_log_det_jacobian_with_caching(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_probability/python/bijectors/bijector.py in _call_inverse(self, y, name, **kwargs)
#     947       if mapping.x is not None:
#     948         return mapping.x
# --> 949       mapping = mapping.merge(x=self._inverse(y, **kwargs))
#     950       # It's most important to cache the x->y mapping, because computing
#     951       # forward(inverse(y)) may be numerically unstable / lossy. Caching the
#
# <ipython-input-89-40ec86dd98ef> in _inverse(self, y)
#      18         #x_tail = y[..., 2:-1]
#      19
# ---> 20         return tf.concat([x_0, x_1, x_tail], axis=-1)
#
# NameError: name 'x_tail' is not defined
