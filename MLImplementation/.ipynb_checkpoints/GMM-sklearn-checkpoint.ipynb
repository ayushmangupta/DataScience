# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')
from sklearn.datasets.samples_generator import make_blobs
import numpy as np
from scipy.stats import multivariate_normal
from sklearn.mixture import GaussianMixture

# %%
plt.figure(figsize=(10,10))
# 0. Create dataset
X,Y = make_blobs(cluster_std=0.5,random_state=20,n_samples=1000,centers=5)
plt.scatter(X[:,0],X[:,1])
#print(X)
#print(Y)
##################################################
###### Stratch dataset to get ellipsoid data######
##################################################
X = np.dot(X,np.random.RandomState(0).randn(2,2))
x,y = np.meshgrid(np.sort(X[:,0]),np.sort(X[:,1]))
XY = np.array([x.flatten(),y.flatten()]).T
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
GMM = GaussianMixture(n_components=5).fit(X) # Instantiate and fit the model
print('Converged:',GMM.converged_) # Check if the model has converged
means = GMM.means_ 
covariances = GMM.covariances_
# Out:
# Converged: True

# %%
# Predict
Y = np.array([[0.5],[0.5]])
prediction = GMM.predict_proba(Y.T)
print(prediction)
# Out:
# [[1.00000000e+00 5.02664415e-44 4.00098007e-33 9.36305075e-82
#   1.94756664e-93]]

# %%
# Plot   
fig = plt.figure(figsize=(10,10))
ax0 = fig.add_subplot(111)
ax0.scatter(X[:,0],X[:,1])
ax0.scatter(Y[0,:],Y[1,:],c='orange',zorder=10,s=100)
for m,c in zip(means,covariances):
    multi_normal = multivariate_normal(mean=m,cov=c)
    ax0.contour(np.sort(X[:,0]),np.sort(X[:,1]),multi_normal.pdf(XY).reshape(len(X),len(X)),colors='black',alpha=0.3)
    
    ax0.scatter(m[0],m[1],c='grey',zorder=10,s=100)
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-776a1828b910> in <module>
#       3 ax0 = fig.add_subplot(111)
#       4 ax0.scatter(X[:,0],X[:,1])
# ----> 5 ax0.scatter(Y[0,:],Y[1,:],c='orange',zorder=10,s=100)
#       6 for m,c in zip(means,covariances):
#       7     multi_normal = multivariate_normal(mean=m,cov=c)
#
# IndexError: too many indices for array

# %%
x = np.arange(-5.0,5.0,0.1)
y = np.arange(-5.0,5.0,0.1)
xx,yy = np.meshgrid(x,y)

# %%
z= np.sin(xx**2 + yy**2)/(xx**2+yy**2)

# %%
plt.contour(z);
